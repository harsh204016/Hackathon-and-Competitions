# %%
#!pip install keras_self_attention

# %%
# Load Libraries
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.layers.recurrent import LSTM, GRU,SimpleRNN

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model , Sequential
from keras.layers import Dense,Embedding,Dropout,Bidirectional,Input,BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
#from keras_self_attention import SeqSelfAttention
import tensorflow as tf


from numpy.random import seed
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   np.random.seed(42)
reset_random_seeds()
np.random.get_state()[1][0]
# Out:
# 42

# %%
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is
    # set: this is always the case on Kaggle.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %%
import os
print(os.listdir("../input"))
# Out:
# ['test.csv', 'challenge_data.csv', 'train.csv']

# %%
train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")
train.shape , test.shape
# Out:
# ((903916, 4), (397320, 4))

# %%
# Create labels
label = train[train.challenge_sequence > 10][['user_id','challenge']]
label.rename(columns={'challenge':'label'},inplace=True)

label.head()
# Out:
#     user_id    label
# 10     4576  CI24958
# 11     4576  CI23667
# 12     4576  CI23691
# 23     4580  CI24915
# 24     4580  CI25727

# %%
# Treat the sequence of challenges as text
df = train[train.challenge_sequence <= 10].groupby('user_id').challenge.aggregate(lambda x: ' '.join(x)).reset_index()
df.shape
# Out:
# (69532, 2)

# %%
df.head()
# Out:
#    user_id                                          challenge
# 0     4576  CI23714 CI23855 CI24917 CI23663 CI23933 CI2513...
# 1     4580  CI23663 CI23855 CI23933 CI23975 CI24530 CI2371...
# 2     4581  CI26155 CI26156 CI26157 CI26158 CI26159 CI2616...
# 3     4582  CI23855 CI24915 CI24917 CI23933 CI23663 CI2495...
# 4     4585  CI23855 CI23975 CI24917 CI25135 CI23848 CI2371...

# %%
# Merge Labels
df = df.merge(label)
df.head()
# Out:
#    user_id                                          challenge    label
# 0     4576  CI23714 CI23855 CI24917 CI23663 CI23933 CI2513...  CI24958
# 1     4576  CI23714 CI23855 CI24917 CI23663 CI23933 CI2513...  CI23667
# 2     4576  CI23714 CI23855 CI24917 CI23663 CI23933 CI2513...  CI23691
# 3     4580  CI23663 CI23855 CI23933 CI23975 CI24530 CI2371...  CI24915
# 4     4580  CI23663 CI23855 CI23933 CI23975 CI24530 CI2371...  CI25727

# %%
df.label.value_counts()
# Out:
# CI25135    1191
# CI23848    1169
# CI24958    1105
# CI23663    1089
# CI23714    1070
#            ...
# CI25478       1
# CI28524       1
# CI25226       1
# CI26326       1
# CI27713       1
# Name: label, Length: 4538, dtype: int64

# %%
# Validation split for early stopping
df_train, df_validation = train_test_split(df.sample(frac=1), test_size=0.1, shuffle=True)
df_train.shape , df_validation.shape
# Out:
# ((187736, 3), (20860, 3))

# %%
df_train.head()
# Out:
#         user_id                                          challenge    label
# 40014     25639  CI23763 CI23765 CI23909 CI23956 CI23703 CI2391...  CI23924
# 76486     44635  CI24188 CI24527 CI24958 CI24531 CI24915 CI2418...  CI24052
# 142104    79141  CI26886 CI26889 CI26898 CI26899 CI26900 CI2690...  CI26221
# 45106     28263  CI28173 CI28177 CI28182 CI28190 CI28188 CI2818...  CI28194
# 107324    60864  CI25142 CI25143 CI25179 CI25180 CI25136 CI2517...  CI24440

# %%
# Load all the challenges
challenges = pd.read_csv('../input/challenge_data.csv')
challenges.head()
# Out:
#   challenge_ID  programming_language challenge_series_ID  total_submissions  \
# 0      CI23478                     2              SI2445               37.0
# 1      CI23479                     2              SI2435               48.0
# 2      CI23480                     1              SI2435               15.0
# 3      CI23481                     1              SI2710              236.0
# 4      CI23482                     2              SI2440              137.0
#
#   publish_date author_ID author_gender author_org_ID  category_id
# 0   06-05-2006  AI563576             M     AOI100001          NaN
# 1   17-10-2002  AI563577             M     AOI100002         32.0
# 2   16-10-2002  AI563578             M     AOI100003          NaN
# 3   19-09-2003  AI563579             M     AOI100004         70.0
# 4   21-03-2002  AI563580             M     AOI100005          NaN

# %%
# Encode challenges
encoder = LabelEncoder()
encoder.fit(challenges['challenge_ID'])
df_train['brand_id_encoded'] = encoder.transform(df_train.label)
df_validation['brand_id_encoded'] = encoder.transform(df_validation.label)
    
# Tokenize text
tokenizer = Tokenizer()
tokenizer.fit_on_texts((df_train['challenge']))

df_train.head()
# Out:
#         user_id                                          challenge    label  \
# 40014     25639  CI23763 CI23765 CI23909 CI23956 CI23703 CI2391...  CI23924
# 76486     44635  CI24188 CI24527 CI24958 CI24531 CI24915 CI2418...  CI24052
# 142104    79141  CI26886 CI26889 CI26898 CI26899 CI26900 CI2690...  CI26221
# 45106     28263  CI28173 CI28177 CI28182 CI28190 CI28188 CI2818...  CI28194
# 107324    60864  CI25142 CI25143 CI25179 CI25180 CI25136 CI2517...  CI24440
#
#         brand_id_encoded
# 40014                446
# 76486                574
# 142104              2743
# 45106               4716
# 107324               962

# %%
# Constants
NB_WORDS = len(tokenizer.word_index)+1
MAX_SEQUENCE_LENGTH = 10
N_CATEGORIES = challenges.shape[0]


print("NB_WORDS",NB_WORDS)
print("MAX_SQUENCE",MAX_SEQUENCE_LENGTH)
print("N_CATEGORIES",N_CATEGORIES)
    
# Create sequences
sequences_train = tokenizer.texts_to_sequences(df_train['challenge'])
sequences_validation = tokenizer.texts_to_sequences(df_validation['challenge'])
    
# Pad sequences
x_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH, padding='post', truncating='post')
x_validation = pad_sequences(sequences_validation, maxlen=MAX_SEQUENCE_LENGTH, padding='post', truncating='post')
    
# Set Labels
y_train = df_train['brand_id_encoded'].values
y_validation= df_validation['brand_id_encoded'].values


x_train
# Out:
# NB_WORDS 4962
# MAX_SQUENCE 10
# N_CATEGORIES 5606
# array([[ 730,  813,  581, ...,  476,  851,  872],
#        [ 147,   15,    5, ...,   51,    1,   21],
#        [ 956,  725,  416, ...,  217,  298,  211],
#        ...,
#        [   2,   75,  641, ...,  269, 1141, 1339],
#        [ 173,   35,   42, ...,  133,   87,  122],
#        [ 126,   61,   96, ...,   38,   26,  107]], dtype=int32)

# %%
x_train.shape
# Out:
# (187736, 10)

# %%
with strategy.scope():
    model = Sequential()
    model.add(Embedding(NB_WORDS,256,
                     input_length=MAX_SEQUENCE_LENGTH))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dropout(0.7))
    model.add(Dense(N_CATEGORIES, activation='softmax'))
    

    model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',
                  metrics=['accuracy'])
    model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 256)           1270272
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               142800
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 5606)              566206
# =================================================================
# Total params: 1,979,278
# Trainable params: 1,979,278
# Non-trainable params: 0
# _________________________________________________________________

# %%
cd /kaggle/working/
# Out:
# /kaggle/working

# %%
    
# Model callbacks
path = 'best_model_weights'
es_callback = EarlyStopping(monitor="val_loss", patience=5,verbose=1)

mc_callback = ModelCheckpoint('{}.hdf5'.format(path), monitor='val_loss',
                              verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=1)
callbacks = [es_callback,mc_callback]

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 256)           1270272
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               142800
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 5606)              566206
# =================================================================
# Total params: 1,979,278
# Trainable params: 1,979,278
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# Fit the model

model.fit(x_train,
              y_train,
              epochs=100,
              batch_size=64*strategy.num_replicas_in_sync,
              validation_data=(x_validation, y_validation),
              callbacks = callbacks
             )
# Out:
# Epoch 1/100
# 367/367 [==============================] - 8s 22ms/step - loss: 7.0637 - accuracy: 0.0068 - val_loss: 6.4307 - val_accuracy: 0.0152
# Epoch 2/100
# 367/367 [==============================] - 5s 13ms/step - loss: 6.1376 - accuracy: 0.0186 - val_loss: 5.7665 - val_accuracy: 0.0269
# Epoch 3/100
# 367/367 [==============================] - 5s 14ms/step - loss: 5.7417 - accuracy: 0.0259 - val_loss: 5.4781 - val_accuracy: 0.0333
# Epoch 4/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.5268 - accuracy: 0.0317 - val_loss: 5.3075 - val_accuracy: 0.0389
# Epoch 5/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.3860 - accuracy: 0.0349 - val_loss: 5.1937 - val_accuracy: 0.0408
# Epoch 6/100
# 367/367 [==============================] - 6s 16ms/step - loss: 5.2844 - accuracy: 0.0389 - val_loss: 5.1096 - val_accuracy: 0.0473
# Epoch 7/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.2060 - accuracy: 0.0408 - val_loss: 5.0421 - val_accuracy: 0.0453
# Epoch 8/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.1392 - accuracy: 0.0430 - val_loss: 4.9862 - val_accuracy: 0.0495
# Epoch 9/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.0829 - accuracy: 0.0440 - val_loss: 4.9436 - val_accuracy: 0.0497
# Epoch 10/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.0434 - accuracy: 0.0456 - val_loss: 4.9093 - val_accuracy: 0.0505
# Epoch 11/100
# 367/367 [==============================] - 5s 13ms/step - loss: 5.0018 - accuracy: 0.0470 - val_loss: 4.8800 - val_accuracy: 0.0528
# Epoch 12/100
# 367/367 [==============================] - 5s 14ms/step - loss: 4.9618 - accuracy: 0.0487 - val_loss: 4.8555 - val_accuracy: 0.0554
# Epoch 13/100
# 367/367 [==============================] - 5s 14ms/step - loss: 4.9302 - accuracy: 0.0504 - val_loss: 4.8317 - val_accuracy: 0.0552
# Epoch 14/100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.9020 - accuracy: 0.0511 - val_loss: 4.8122 - val_accuracy: 0.0547
# Epoch 15/100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.8745 - accuracy: 0.0533 - val_loss: 4.7898 - val_accuracy: 0.0565
# Epoch 16/100
# 367/367 [==============================] - 5s 14ms/step - loss: 4
100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.3691 - accuracy: 0.0884 - val_loss: 4.5583 - val_accuracy: 0.0784
# Epoch 74/100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.3587 - accuracy: 0.0887 - val_loss: 4.5607 - val_accuracy: 0.0775
# Epoch 75/100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.3576 - accuracy: 0.0894 - val_loss: 4.5642 - val_accuracy: 0.0763
# Epoch 76/100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.3565 - accuracy: 0.0885 - val_loss: 4.5600 - val_accuracy: 0.0752
# Epoch 77/100
# 367/367 [==============================] - 5s 13ms/step - loss: 4.3559 - accuracy: 0.0882 - val_loss: 4.5588 - val_accuracy: 0.0768
# Epoch 00077: early stopping
# CPU times: user 2min 48s, sys: 31.1 s, total: 3min 19s
# Wall time: 6min 31s

# %%
cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# Test preprocessing
def padding(text):
    return pad_sequences(tokenizer.texts_to_sequences(text), maxlen=MAX_SEQUENCE_LENGTH, padding='post', truncating='post')
test_text = test[test.challenge_sequence <= 10].groupby('user_id').challenge.aggregate(lambda x: ' '.join(x)).reset_index()
x_test = padding(test_text.challenge)

# Get top 3 predictions for each user
pred = model.predict(x_test,batch_size=2048)
pred = pred.argsort(axis=1)[:,-3:][:,::-1]

# %%
# Test preprocessing
def padding(text):
    return pad_sequences(tokenizer.texts_to_sequences(text), maxlen=MAX_SEQUENCE_LENGTH, padding='post', truncating='post')
test_text = test[test.challenge_sequence <= 10].groupby('user_id').challenge.aggregate(lambda x: ' '.join(x)).reset_index()
x_test = padding(test_text.challenge)

# Get top 3 predictions for each user
pred = model.predict(x_test,batch_size=2048)
pred = pred.argsort(axis=1)[:,-3:][:,::-1]

# %%
pred.shape

# %%
df_list = []
for i in range(3):
    test_11 = test_text[['user_id']]
    test_11['user_sequence'] = test_11.user_id.astype(str) + '_'+str(i+11)
    test_11['challenge'] = encoder.inverse_transform(pred[:,i])
    df_list.append(test_11[['user_sequence','challenge']])
pd.concat(df_list).to_csv('bes2_submission.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-aa5f8dc88dbf> in <module>
#       3     test_11 = test_text[['user_id']]
#       4     test_11['user_sequence'] = test_11.user_id.astype(str) + '_'+str(i+11)
# ----> 5     test_11['challenge'] = encoder.inverse_transform(pred[:,i])
#       6     df_list.append(test_11[['user_sequence','challenge']])
#       7 pd.concat(df_list).to_csv('bes2_submission.csv',index=False)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
pwd

# %%
pd.concat(df_list).to_csv('submission.csv',index=False)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Embedding(input_dim=10000,
                                 output_dim=300,
                                 mask_zero=True))
model.add(keras.layers.Bidirectional(keras.layers.LSTM(units=128,
                                                       return_sequences=True)))
model.add(SeqSelfAttention(attention_activation='sigmoid'))
model.add(keras.layers.Dense(units=5))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy'],
)
model.summary()

# %%
with strategy.scope():
    # GRU with glove embeddings and two dense layers
     model = Sequential()
     model.add(Embedding(len(word_index) + 1,
                     300,
                     input_length=max_len,
                     trainable=False))
     model.add(SpatialDropout1D(0.3))
     model.add(GRU(300))
     model.add(Dense(1, activation='sigmoid'))

     model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
